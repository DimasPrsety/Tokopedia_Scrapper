# %%
from airflow import DAG
from datetime import datetime
from airflow.operators.dummy import DummyOperator

with DAG(
    dag_id='test_dag',
    schedule_interval='@daily',
    start_date=datetime(2024, 1, 1),
    catchup=False,
) as dag:
    task = DummyOperator(task_id='dummy_task')
# Out:
# Unable to load the config, contains a configuration error.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/logging/config.py:105, in _resolve(name)
#     104 try:
# --> 105     found = getattr(found, n)
#     106 except AttributeError:
#
# AttributeError: partially initialized module 'airflow' has no attribute 'utils' (most likely due to a circular import)
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/logging/config.py:587, in DictConfigurator.configure(self)
#     586 try:
# --> 587     formatters[name] = self.configure_formatter(
#     588                                         formatters[name])
#     589 except Exception as e:
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/logging/config.py:720, in DictConfigurator.configure_formatter(self, config)
#     719 else:
# --> 720     c = _resolve(cname)
#     722 kwargs  = {}
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/logging/config.py:108, in _resolve(name)
#     107         __import__(used)
# --> 108         found = getattr(found, n)
#     109 return found
#
# AttributeError: partially initialized module 'airflow' has no attribute 'utils' (most likely due to a circular import)
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 from airflow import DAG
#       2 from datetime import datetime
#       3 from airflow.operators.dummy import DummyOperator
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/airflow/__init__.py:74
#      68 # Perform side-effects unless someone has explicitly opted out before import
#      69 # WARNING: DO NOT USE THIS UNLESS YOU REALLY KNOW WHAT YOU'RE DOING.
#      70 # This environment variable prevents proper initialization, and things like
#      71 # configs, logging, the ORM, etc. will be broken. It is only useful if you only
#      72 # access certain trivial constants and free functions (e.g. `__version__`).
#      73 if not os.environ.get("_AIRFLOW__AS_LIBRARY", None):
# ---> 74     settings.initialize()
#      76 # Things to lazy import in form {local_name: ('target_module', 'target_name', 'deprecated')}
#      77 __lazy_imports: dict[str, tuple[str, str, bool]] = {
#      78     "DAG": (".models.dag", "DAG", False),
#      79     "Dataset": (".datasets", "Dataset", False),
#    (...)
#      83     "AirflowException": (".exceptions", "AirflowException", True),
#      84 }
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/airflow/settings.py:785, in initialize()
#     783 prepare_syspath_for_dags_folder()
#     784 global LOGGING_CLASS_PATH
# --> 785 LOGGING_CLASS_PATH = configure_logging()
#     786 State.state_color.update(STATE_COLORS)
#     788 configure_adapters()
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/airflow/logging_config.py:74, in configure_logging()
#      71     log.error("Unable to load the config, contains a configuration error.")
#      72     # When there is an error in the config, escalate the exception
#      73     # otherwise Airflow would silently fall back on the default config
# ---> 74     raise e
#      76 validate_logging_config(logging_config)
#      78 return logging_class_path
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/airflow/logging_config.py:69, in configure_logging()
#      66             task_handler_config["filters"].append("mask_secrets")
#      68     # Try to init logging
# ---> 69     dictConfig(logging_config)
#      70 except (ValueError, KeyError) as e:
#      71     log.error("Unable to load the config, contains a configuration error.")
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/logging/config.py:942, in dictConfig(config)
#     940 def dictConfig(config):
#     941     """Configure logging using a dictionary."""
# --> 942     dictConfigClass(config).configure()
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/logging/config.py:590, in DictConfigurator.configure(self)
#     587         formatters[name] = self.configure_formatter(
#     588                                             formatters[name])
#     589     except Exception as e:
# --> 590         raise ValueError('Unable to configure '
#     591                          'formatter %r' % name) from e
#     592 # Next, do filters - they don't refer to anything else, either
#     593 filters = config.get('filters', EMPTY_DICT)
#
# ValueError: Unable to configure formatter 'airflow'

# %%
pip install apache-airflow
# Out:
# Requirement already satisfied: apache-airflow in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (2.10.2)
# Requirement already satisfied: alembic<2.0,>=1.13.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from apache-airflow) (1.13.3)
# Requirement already satisfied: argcomplete>=1.10 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from apache-airflow) (3.5.0)
# Requirement already satisfied: asgiref>=2.3.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from apache-airflow) (3.8.1)
# Requirement already satisfied: attrs>=22.1.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from apache-airflow) (24.2.0)
# Requirement already satisfied: blinker>=1.6.2 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from apache-airflow) (1.8.2)
# Requirement already satisfied: colorlog>=6.8.2 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from apache-airflow) (6.8.2)
# Requirement already satisfied: configupdater>=3.1.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from apache-airflow) (3.2)
# Requirement already satisfied: connexion<3.0,>=2.14.2 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from connexion[flask]<3.0,>=2.14.2->apache-airflow) (2.14.2)
# Requirement already satisfied: cron-descriptor>=1.2.24 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from apache-airflow) (1.4.5)
# Requirement already satisfied: croniter>=2.0.2 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from apache-airflow) (3.0.3)
# Requirement already satisfied: cryptography>=41.0.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from apache-airflow) (43.0.1)
# Requirement already satisfied: deprecated>=1.2.13 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from apache-airflow) (1.2.14)
# Requirement already satisfied: dill>=0.2.2 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from apache-airflow) (0.3.8)
# Requirement already satisfied: flask-caching>=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from apache-airflow) (2.3.0)
# Requirement already satisfied: flask-session<0.6,>=0.4.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from apache-airflow) (0.5.0)
# Requirement already satisfied: flask-wtf>=1.1.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from apache-airflow) (1.2.1)
# Requirement already satisfied: flask<2.3,>=2.2.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from apache-airflow) (2.2.5)
# Requirement already satisfied: fsspec>=2023.10.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from apache-airflow) (2024.9.0)
# Requirement already satisfied: google-re2>=1.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from apache-airflow) (1.1.20240702)
# Requirement already satisfied: gunicorn>=20.1.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from apache-airflow) (23.0.0)
# Requirement already satisfied: httpx>=0.25.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from apache-airflow) (0.27.2)
# Requirement already satisfied: itsdangerous>=2.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from apache-airflow) (2.2.0)
# Requirement already satisfied: jinja2>=3.0.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from apache-airflow) (3.1.4)
# Requirement already satisfied: jsonschema>=4.18.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from apache-airflow) (4.23.0)
# Requirement already satisfied: lazy-object-proxy>=1.2.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from apache-airflow) (1.10.0)
# Requirement already satisfied: linkify-it-py>=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from apache-airflow) (2.0.3)
# Requirement already satisfied: lockfile>=0.12.2 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from apache-airflow) (0.12.2)
# Requirement already satisfied: markdown-it-py>=2.1.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from apache-airflow) (3.0.0)
# Requirement already satisfied: markupsafe>=1.1.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from apache-airflow) (2.1.5)
# Requirement already satisfied: marshmallow-oneofschema>=2.0.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from apache-airflow) (3.1.1)
# Requirement already satisfied: mdit-py-plugins>=0.3.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from apache-airflow) (0.4.2)
# Requirement already satisfied: methodtools>=0.4.7 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from apache-airflow) (0.4.7)
# Requirement already satisfied: opentelemetry-api>=1.15.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from apache-airflow) (1.27.0)
# Requirement already satisfied: opentelemetry-exporter-otlp>=1.15.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from apache-airflow) (1.27.0)
# Requirement already satisfied: packaging>=23.0 in /Users/efishery/Library/Python/3.12/lib/python/site-packages (from apache-airflow) (24.1)
# Requirement already satisfied: pathspec>=0.9.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from apache-airflow) (0.12.1)
# Requirement already satisfied: pendulum<4.0,>=3.0.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from apache-airflow) (3.0.0)
# Requirement already satisfied: pluggy>=1.5.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from apache-airflow) (1.5.0)
# Requirement already satisfied: psutil>=5.8.0 in /Users/efishery/Library/Python/3.12/lib/python/site-packages (from apache-airflow) (6.0.0)
# Requirement already satisfied: pygments>=2.0.1 in /Users/efishery/Library/Python/3.12/lib/python/site-packages (from apache-airflow) (2.18.0)
# Requirement already satisfied: pyjwt>=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from apache-airflow) (2.9.0)
# Requirement already satisfied: python-daemon>=3.0.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from apache-airflow) (3.0.1)
# Requirement already satisfied: python-dateutil>=2.7.0 in /Users/efishery/Library/Python/3.12/lib/python/site-packages (from apache-airflow) (2.9.0.post0)
# Requirement already satisfied: python-nvd3>=0.15.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from apache-airflow) (0.16.0)
# Requirement already satisfied: python-slugify>=5.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from apache-airflow) (8.0.4)
# Requirement already satisfied: requests<3,>=2.27.0 in /Users/efishery/Library/Python/3.12/lib/python/site-packages (from apache-airflow) (2.32.3)
# Requirement already satisfied: requests-toolbelt>=0.4.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from apache-airflow) (1.0.0)
# Requirement already satisfied: rfc3339-validator>=0.1.4 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from apache-airflow) (0.1.4)
# Requirement already satisfied: rich-argparse>=1.0.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from apache-airflow) (1.5.2)
# Requirement already satisfied: rich>=12.4.4 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from apache-airflow) (13.8.1)
# Requirement already satisfied: setproctitle>=1.3.3 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from apache-airflow) (1.3.3)
# Collecting sqlalchemy<2.0,>=1.4.36 (from apache-airflow)
#   Using cached SQLAlchemy-1.4.54-cp312-cp312-macosx_10_9_universal2.whl.metadata (10 kB)
# Requirement already satisfied: sqlalchemy-jsonfield>=1.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from apache-airflow) (1.0.2)
# Requirement already satisfied: tabulate>=0.7.5 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from apache-airflow) (0.9.0)
# Requirement already satisfied: tenacity!=8.2.0,>=8.0.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from apache-airflow) (9.0.0)
# Requirement already satisfied: termcolor>=1.1.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from apache-airflow) (2.4.0)
# Requirement already satisfied: unicodecsv>=0.14.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from apache-airflow) (0.14.1)
# Requirement already satisfied: universal-pathlib!=0.2.4,>=0.2.2 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from apache-airflow) (0.2.5)
# Requirement already satisfied: werkzeug<3,>=2.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from apache-airflow) (2.2.3)
# Requirement already satisfied: apache-airflow-providers-common-compat in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from apache-airflow) (1.2.0)
# Requirement already satisfied: apache-airflow-providers-common-io in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from apache-airflow) (1.4.1)
# Requirement already satisfied: apache-airflow-providers-common-sql in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from apache-airflow) (1.17.0)
# Requirement already satisfied: apache-airflow-providers-fab>=1.0.2 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from apache-airflow) (1.4.0)
# Requirement already satisfied: apache-airflow-providers-ftp in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from apache-airflow) (3.11.1)
# Requirement already satisfied: apache-airflow-providers-http in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from apache-airflow) (4.13.1)
# Requirement already satisfied: apache-airflow-providers-imap in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from apache-airflow) (3.7.0)
# Requirement already satisfied: apache-airflow-providers-smtp in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from apache-airflow) (1.8.0)
# Requirement already satisfied: apache-airflow-providers-sqlite in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from apache-airflow) (3.9.0)
# Requirement already satisfied: Mako in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from alembic<2.0,>=1.13.1->apache-airflow) (1.3.5)
# Requirement already satisfied: typing-extensions>=4 in /Users/efishery/Library/Python/3.12/lib/python/site-packages (from alembic<2.0,>=1.13.1->apache-airflow) (4.12.2)
# Requirement already satisfied: flask-appbuilder==4.5.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from apache-airflow-providers-fab>=1.0.2->apache-airflow) (4.5.0)
# Requirement already satisfied: flask-login>=0.6.2 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from apache-airflow-providers-fab>=1.0.2->apache-airflow) (0.6.3)
# Requirement already satisfied: jmespath>=0.7.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from apache-airflow-providers-fab>=1.0.2->apache-airflow) (1.0.1)
# Requirement already satisfied: apispec<7,>=6.0.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from apispec[yaml]<7,>=6.0.0->flask-appbuilder==4.5.0->apache-airflow-providers-fab>=1.0.2->apache-airflow) (6.6.1)
# Requirement already satisfied: colorama<1,>=0.3.9 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from flask-appbuilder==4.5.0->apache-airflow-providers-fab>=1.0.2->apache-airflow) (0.4.6)
# Requirement already satisfied: click<9,>=8 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from flask-appbuilder==4.5.0->apache-airflow-providers-fab>=1.0.2->apache-airflow) (8.1.7)
# Requirement already satisfied: email-validator>=1.0.5 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from flask-appbuilder==4.5.0->apache-airflow-providers-fab>=1.0.2->apache-airflow) (2.2.0)
# Requirement already satisfied: Flask-Babel<3,>=1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from flask-appbuilder==4.5.0->apache-airflow-providers-fab>=1.0.2->apache-airflow) (2.0.0)
# Requirement already satisfied: Flask-Limiter<4,>3 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from flask-appbuilder==4.5.0->apache-airflow-providers-fab>=1.0.2->apache-airflow) (3.8.0)
# Requirement already satisfied: Flask-SQLAlchemy<3,>=2.4 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from flask-appbuilder==4.5.0->apache-airflow-providers-fab>=1.0.2->apache-airflow) (2.5.1)
# Requirement already satisfied: Flask-JWT-Extended<5.0.0,>=4.0.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from flask-appbuilder==4.5.0->apache-airflow-providers-fab>=1.0.2->apache-airflow) (4.6.0)
# Requirement already satisfied: marshmallow<4,>=3.18.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from flask-appbuilder==4.5.0->apache-airflow-providers-fab>=1.0.2->apache-airflow) (3.22.0)
# Requirement already satisfied: marshmallow-sqlalchemy<0.29.0,>=0.22.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from flask-appbuilder==4.5.0->apache-airflow-providers-fab>=1.0.2->apache-airflow) (0.28.2)
# Requirement already satisfied: prison<1.0.0,>=0.2.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from flask-appbuilder==4.5.0->apache-airflow-providers-fab>=1.0.2->apache-airflow) (0.2.1)
# Requirement already satisfied: sqlalchemy-utils<1,>=0.32.21 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from flask-appbuilder==4.5.0->apache-airflow-providers-fab>=1.0.2->apache-airflow) (0.41.2)
# Requirement already satisfied: WTForms<4 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from flask-appbuilder==4.5.0->apache-airflow-providers-fab>=1.0.2->apache-airflow) (3.1.2)
# Requirement already satisfied: clickclick<21,>=1.2 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from connexion<3.0,>=2.14.2->connexion[flask]<3.0,>=2.14.2->apache-airflow) (20.10.2)
# Requirement already satisfied: PyYAML<7,>=5.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from connexion<3.0,>=2.14.2->connexion[flask]<3.0,>=2.14.2->apache-airflow) (6.0.2)
# Requirement already satisfied: inflection<0.6,>=0.3.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from connexion<3.0,>=2.14.2->connexion[flask]<3.0,>=2.14.2->apache-airflow) (0.5.1)
# Requirement already satisfied: pytz>2021.1 in /Users/efishery/Library/Python/3.12/lib/python/site-packages (from croniter>=2.0.2->apache-airflow) (2024.2)
# Requirement already satisfied: cffi>=1.12 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from cryptography>=41.0.0->apache-airflow) (1.17.1)
# Requirement already satisfied: wrapt<2,>=1.10 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from deprecated>=1.2.13->apache-airflow) (1.16.0)
# Requirement already satisfied: cachelib<0.10.0,>=0.9.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from flask-caching>=2.0.0->apache-airflow) (0.9.0)
# Requirement already satisfied: anyio in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from httpx>=0.25.0->apache-airflow) (4.6.0)
# Requirement already satisfied: certifi in /Users/efishery/Library/Python/3.12/lib/python/site-packages (from httpx>=0.25.0->apache-airflow) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from httpx>=0.25.0->apache-airflow) (1.0.5)
# Requirement already satisfied: idna in /Users/efishery/Library/Python/3.12/lib/python/site-packages (from httpx>=0.25.0->apache-airflow) (3.10)
# Requirement already satisfied: sniffio in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from httpx>=0.25.0->apache-airflow) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from httpcore==1.*->httpx>=0.25.0->apache-airflow) (0.14.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from jsonschema>=4.18.0->apache-airflow) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from jsonschema>=4.18.0->apache-airflow) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from jsonschema>=4.18.0->apache-airflow) (0.20.0)
# Requirement already satisfied: uc-micro-py in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from linkify-it-py>=2.0.0->apache-airflow) (1.0.3)
# Requirement already satisfied: mdurl~=0.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from markdown-it-py>=2.1.0->apache-airflow) (0.1.2)
# Requirement already satisfied: wirerope>=0.4.7 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from methodtools>=0.4.7->apache-airflow) (0.4.7)
# Requirement already satisfied: importlib-metadata<=8.4.0,>=6.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from opentelemetry-api>=1.15.0->apache-airflow) (8.4.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc==1.27.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from opentelemetry-exporter-otlp>=1.15.0->apache-airflow) (1.27.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-http==1.27.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from opentelemetry-exporter-otlp>=1.15.0->apache-airflow) (1.27.0)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from opentelemetry-exporter-otlp-proto-grpc==1.27.0->opentelemetry-exporter-otlp>=1.15.0->apache-airflow) (1.65.0)
# Requirement already satisfied: grpcio<2.0.0,>=1.0.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from opentelemetry-exporter-otlp-proto-grpc==1.27.0->opentelemetry-exporter-otlp>=1.15.0->apache-airflow) (1.66.1)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.27.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from opentelemetry-exporter-otlp-proto-grpc==1.27.0->opentelemetry-exporter-otlp>=1.15.0->apache-airflow) (1.27.0)
# Requirement already satisfied: opentelemetry-proto==1.27.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from opentelemetry-exporter-otlp-proto-grpc==1.27.0->opentelemetry-exporter-otlp>=1.15.0->apache-airflow) (1.27.0)
# Requirement already satisfied: opentelemetry-sdk~=1.27.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from opentelemetry-exporter-otlp-proto-grpc==1.27.0->opentelemetry-exporter-otlp>=1.15.0->apache-airflow) (1.27.0)
# Requirement already satisfied: protobuf<5.0,>=3.19 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from opentelemetry-proto==1.27.0->opentelemetry-exporter-otlp-proto-grpc==1.27.0->opentelemetry-exporter-otlp>=1.15.0->apache-airflow) (4.25.5)
# Requirement already satisfied: tzdata>=2020.1 in /Users/efishery/Library/Python/3.12/lib/python/site-packages (from pendulum<4.0,>=3.0.0->apache-airflow) (2024.1)
# Requirement already satisfied: time-machine>=2.6.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pendulum<4.0,>=3.0.0->apache-airflow) (2.15.0)
# Requirement already satisfied: docutils in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from python-daemon>=3.0.0->apache-airflow) (0.21.2)
# Requirement already satisfied: setuptools>=62.4.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from python-daemon>=3.0.0->apache-airflow) (75.1.0)
# Requirement already satisfied: six>=1.5 in /Users/efishery/Library/Python/3.12/lib/python/site-packages (from python-dateutil>=2.7.0->apache-airflow) (1.16.0)
# Requirement already satisfied: text-unidecode>=1.3 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from python-slugify>=5.0->apache-airflow) (1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/efishery/Library/Python/3.12/lib/python/site-packages (from requests<3,>=2.27.0->apache-airflow) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/efishery/Library/Python/3.12/lib/python/site-packages (from requests<3,>=2.27.0->apache-airflow) (2.2.3)
# Requirement already satisfied: more-itertools>=9.0.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from apache-airflow-providers-common-sql->apache-airflow) (10.5.0)
# Requirement already satisfied: sqlparse>=0.4.2 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from apache-airflow-providers-common-sql->apache-airflow) (0.5.1)
# Requirement already satisfied: aiohttp>=3.9.2 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from apache-airflow-providers-http->apache-airflow) (3.10.7)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from aiohttp>=3.9.2->apache-airflow-providers-http->apache-airflow) (2.4.2)
# Requirement already satisfied: aiosignal>=1.1.2 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from aiohttp>=3.9.2->apache-airflow-providers-http->apache-airflow) (1.3.1)
# Requirement already satisfied: frozenlist>=1.1.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from aiohttp>=3.9.2->apache-airflow-providers-http->apache-airflow) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from aiohttp>=3.9.2->apache-airflow-providers-http->apache-airflow) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from aiohttp>=3.9.2->apache-airflow-providers-http->apache-airflow) (1.13.1)
# Requirement already satisfied: pycparser in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from cffi>=1.12->cryptography>=41.0.0->apache-airflow) (2.22)
# Requirement already satisfied: zipp>=0.5 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from importlib-metadata<=8.4.0,>=6.0->opentelemetry-api>=1.15.0->apache-airflow) (3.20.2)
# Requirement already satisfied: dnspython>=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from email-validator>=1.0.5->flask-appbuilder==4.5.0->apache-airflow-providers-fab>=1.0.2->apache-airflow) (2.6.1)
# Requirement already satisfied: Babel>=2.3 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from Flask-Babel<3,>=1->flask-appbuilder==4.5.0->apache-airflow-providers-fab>=1.0.2->apache-airflow) (2.16.0)
# Requirement already satisfied: limits>=3.13 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from Flask-Limiter<4,>3->flask-appbuilder==4.5.0->apache-airflow-providers-fab>=1.0.2->apache-airflow) (3.13.0)
# Requirement already satisfied: ordered-set<5,>4 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from Flask-Limiter<4,>3->flask-appbuilder==4.5.0->apache-airflow-providers-fab>=1.0.2->apache-airflow) (4.1.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.48b0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from opentelemetry-sdk~=1.27.0->opentelemetry-exporter-otlp-proto-grpc==1.27.0->opentelemetry-exporter-otlp>=1.15.0->apache-airflow) (0.48b0)
# Requirement already satisfied: importlib-resources>=1.3 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from limits>=3.13->Flask-Limiter<4,>3->flask-appbuilder==4.5.0->apache-airflow-providers-fab>=1.0.2->apache-airflow) (6.4.5)
# Using cached SQLAlchemy-1.4.54-cp312-cp312-macosx_10_9_universal2.whl (1.6 MB)
# Installing collected packages: sqlalchemy
#   Attempting uninstall: sqlalchemy
#     Found existing installation: SQLAlchemy 2.0.35
#     Uninstalling SQLAlchemy-2.0.35:
#       Successfully uninstalled SQLAlchemy-2.0.35
# Successfully installed sqlalchemy-1.4.54
# Note: you may need to restart the kernel to use updated packages.
